# %%
# Intensity Histogram

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy.stats import norm

# read and display out .tif file.
ex_image = plt.imread("rfp-3.tif")
plt.figure(figsize=(8, 6), dpi=80)
# show image using a grayscale colourmap. 
plt.imshow(ex_image, cmap='gray');
plt.xlabel("x pixel", fontsize=15)
plt.ylabel("y pixel", fontsize=15)
# Out:
# Text(0, 0.5, 'y pixel')

# %%
# flatten the array representing the image.
I_vec = ex_image.flatten()
(mu, sigma) = norm.fit(I_vec)
# construct a figure using similar parameters.
plt.figure(num=None, figsize=(8, 6), dpi=80)
# make histogram
#n, bins, patches = plt.hist(I_vec, bins=2000, color=[0, 0.5, 1], alpha=0.75)
#y = mlab.normpdf( bins, mu, sigma)
#l = plt.plot(bins, y, 'r--', linewidth=2)
plt.hist(I_vec, bins=2000, color=[0,0.5,1])
plt.xlabel("Intensity Value [A.U.]", fontsize=15)
plt.ylabel("Bin Count [#]", fontsize=15)
#plt.xlim(left=3000)
bin_max = np.where(n == n.max())
print("maxbin_low", b[bin_max][0])
# Out:
# maxbin_low 2238.6710000000003

# %%
cutoff = b[b > 3000]
new_max = np.where(n_new == n_new.max())
print("newmaxbin", cutoff[new_max][0])
# Out:
# newmaxbin 4839.75

# %%
dude = plt.hist(I_vec, bins=100, color=[0,0.5,1], range=(3000, 16000))

# %%
plt.plot(dude[0])
